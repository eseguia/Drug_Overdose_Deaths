# %% [markdown]
# ## Drug Overdose Deaths - a Descriptive and Inferential Analysis
#
# Dataset: https://www.kaggle.com/datasets/ruchi798/drug-overdose-deaths
#
# Questions asked:
# - What is the distribution of ages, sexes, and races? Who is the most affected?
# - What is the distribution of places of residence?
# - Has the magnitude of overdose deaths changed over time? If so, how much?
# - How has overdose frequency by a given drug changed over time?
# - Where do the majority of overdose deaths occur?

# %% [markdown]
# - I. Cleaning Data
# - II. Descriptive Analysis
#   - Demographic Information
# - III. Inferential Analysis
#   - Review of Hypothesis Testing
#   - Z-test
#   - T-test
# - IV. Summary and Conclusion

# %% [markdown]
# ## I. Cleaning Data

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("drug_deaths.csv")
df
# Out:
#       Unnamed: 0       ID                    Date  DateType   Age     Sex  \
# 0              0  14-0273  06/28/2014 12:00:00 AM       1.0   NaN     NaN
# 1              1  13-0102  03/21/2013 12:00:00 AM       0.0  48.0    Male
# 2              2  16-0165  03/13/2016 12:00:00 AM       0.0  30.0  Female
# 3              3  16-0208  03/31/2016 12:00:00 AM       0.0  23.0    Male
# 4              4  13-0052  02/13/2013 12:00:00 AM       0.0  22.0    Male
# ...          ...      ...                     ...       ...   ...     ...
# 5100        5100  15-0466  09/08/2015 12:00:00 AM       1.0  43.0    Male
# 5101        5101  17-0618  07/22/2017 12:00:00 AM       1.0  21.0    Male
# 5102        5102  18-0646  08/14/2018 12:00:00 AM       0.0  30.0    Male
# 5103        5103  14-0124  03/16/2014 12:00:00 AM       0.0  33.0    Male
# 5104        5104  16-0637  09/15/2016 12:00:00 AM       0.0  33.0    Male
#
#               Race  ResidenceCity ResidenceCounty ResidenceState  ... Tramad  \
# 0              NaN            NaN             NaN            NaN  ...      0
# 1            Black        NORWALK             NaN            NaN  ...      0
# 2            White     SANDY HOOK       FAIRFIELD             CT  ...      0
# 3            White            RYE     WESTCHESTER             NY  ...      0
# 4     Asian, Other       FLUSHING          QUEENS            NaN  ...      0
# ...            ...            ...             ...            ...  ...    ...
# 5100         White       CHESHIRE       NEW HAVEN             CT  ...      0
# 5101         White        MADISON       NEW HAVEN             CT  ...      0
# 5102         White  LAWRENCEVILLE           TIOGA             PA  ...      1
# 5103         White       HARTFORD             NaN            NaN  ...      0
# 5104         White      THOMASTON      LITCHFIELD             CT  ...      0
#
#      Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# 0                     0             0   NaN         0         0      Accident
# 1                     0             0   NaN         0         0      Accident
# 2                     0             0   NaN         0         1      Accident
# 3                     0             0   NaN         0         1      Accident
# 4                     0             0   NaN         0         0      Accident
# ...                 ...           ...   ...       ...       ...           ...
# 5100                  0             0   NaN         0         0      Accident
# 5101                  0             0   NaN         0         0      Accident
# 5102                  0             0   NaN         0         1      Accident
# 5103                  0             0   NaN         0         0      Accident
# 5104                  0             0   NaN         0         1      Accident
#
#                                 DeathCityGeo  \
# 0                CT\n(41.575155, -72.738288)
# 1        Norwalk, CT\n(41.11805, -73.412906)
# 2       Danbury, CT\n(41.393666, -73.451539)
# 3     Greenwich, CT\n(41.026526, -73.628549)
# 4     Greenwich, CT\n(41.026526, -73.628549)
# ...                                      ...
# 5100   CHESHIRE, CT\n(41.498834, -72.901448)
# 5101  New Haven, CT\n(41.308252, -72.924161)
# 5102    DANBURY, CT\n(41.393666, -73.451539)
# 5103     WINDSOR, CT\n(41.852781, -72.64379)
# 5104  WATERBURY, CT\n(41.554261, -73.043069)
#
#                              ResidenceCityGeo  \
# 0                 CT\n(41.575155, -72.738288)
# 1         NORWALK, CT\n(41.11805, -73.412906)
# 2     SANDY HOOK, CT\n(41.419998, -73.282501)
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 5100    CHESHIRE, CT\n(41.498834, -72.901448)
# 5101      MADISON, CT\n(41.271447, -72.60086)
# 5102                                      NaN
# 5103    HARTFORD, CT\n(41.765775, -72.673356)
# 5104   THOMASTON, CT\n(41.674124, -73.073189)
#
#                                    InjuryCityGeo
# 0                    CT\n(41.575155, -72.738288)
# 1                    CT\n(41.575155, -72.738288)
# 2                                            NaN
# 3                                            NaN
# 4                    CT\n(41.575155, -72.738288)
# ...                                          ...
# 5100                 CT\n(41.575155, -72.738288)
# 5101                 CT\n(41.575155, -72.738288)
# 5102        DANBURY, CT\n(41.393666, -73.451539)
# 5103                 CT\n(41.575155, -72.738288)
# 5104  WATERBURY, CT, CT\n(41.554261, -73.043069)
#
# [5105 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5101 entries, 1 to 5104
# Data columns (total 42 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5101 non-null   int64
#  1   ID                   5101 non-null   object
#  2   Date                 5101 non-null   datetime64[ns]
#  3   DateType             5101 non-null   float64
#  4   Age                  5101 non-null   int32
#  5   Sex                  5098 non-null   object
#  6   Race                 5091 non-null   object
#  7   ResidenceCity        4932 non-null   object
#  8   ResidenceCounty      4308 non-null   object
#  9   ResidenceState       3556 non-null   object
#  10  DeathCity            5100 non-null   object
#  11  DeathCounty          4005 non-null   object
#  12  Location             5081 non-null   object
#  13  LocationifOther      590 non-null    object
#  14  DescriptionofInjury  4324 non-null   object
#  15  InjuryPlace          5036 non-null   object
#  16  InjuryCity           3347 non-null   object
#  17  InjuryCounty         2362 non-null   object
#  18  InjuryState          1422 non-null   object
#  19  COD                  5101 non-null   object
#  20  OtherSignifican      168 non-null    object
#  21  Heroin               5101 non-null   int64
#  22  Cocaine              5101 non-null   int64
#  23  Fentanyl             5101 non-null   object
#  24  Fentanyl_Analogue    5101 non-null   int32
#  25  Oxycodone            5101 non-null   int64
#  26  Oxymorphone          5101 non-null   int64
#  27  Ethanol              5101 non-null   int64
#  28  Hydrocodone          5101 non-null   int64
#  29  Benzodiazepine       5101 non-null   int64
#  30  Methadone            5101 non-null   int64
#  31  Amphet               5101 non-null   int64
#  32  Tramad               5101 non-null   int64
#  33  Morphine_NotHeroin   5101 non-null   object
#  34  Hydromorphone        5101 non-null   int64
#  35  Other                434 non-null    object
#  36  OpiateNOS            5101 non-null   int64
#  37  AnyOpioid            5101 non-null   object
#  38  MannerofDeath        5093 non-null   object
#  39  DeathCityGeo         5101 non-null   object
#  40  ResidenceCityGeo     5008 non-null   object
#  41  InjuryCityGeo        5023 non-null   object
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(13), object(25)
# memory usage: 1.6+ MB

# %%
# Convert age from float to int
df.dropna(subset = ['Age'], inplace=True)
df = df.astype({'Age':'int'})

# %%
# Convert Fentanyl dtype to int, like all other drugs
df = df.astype({'Fentanyl_Analogue':'int'})

# %%
# Convert our Date column to datetime format. And drop a single null row
df.dropna(subset = ['Date'], inplace=True)
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Create new columns for year, month, day
df['year'] = pd.DatetimeIndex(df['Date']).year
df['month'] = pd.DatetimeIndex(df['Date']).month
df['day'] = pd.DatetimeIndex(df['Date']).day

df = df.astype({'month':'int'})
df = df.astype({'year':'int'})

# %%
df['MannerofDeath'].unique()
# Out:
# array(['Accident', 'accident', nan, 'Pending', 'ACCIDENT', 'Natural'],
#       dtype=object)

# %%
# Some values on the manner of death column are not capitalized consistently with the others
df['MannerofDeath'] = df['MannerofDeath'].str.upper()
df['MannerofDeath'].unique()
# Out:
# array(['ACCIDENT', nan, 'PENDING', 'NATURAL'], dtype=object)

# %%
df.describe()
# Out:
#         Unnamed: 0     DateType          Age       Heroin      Cocaine  \
# count  5103.000000  5103.000000  5101.000000  5103.000000  5103.000000
# mean   2552.472271     0.446992    41.967653     0.495591     0.297864
# std    1473.689567     0.497231    12.336298     0.500030     0.457364
# min       0.000000     0.000000    14.000000     0.000000     0.000000
# 25%    1276.500000     0.000000    32.000000     0.000000     0.000000
# 50%    2552.000000     0.000000    42.000000     0.000000     0.000000
# 75%    3828.500000     1.000000    52.000000     1.000000     1.000000
# max    5104.000000     1.000000    87.000000     1.000000     1.000000
#
#        Fentanyl_Analogue    Oxycodone  Oxymorphone      Ethanol  Hydrocodone  \
# count        5103.000000  5103.000000  5103.000000  5103.000000  5103.000000
# mean            0.076230     0.118950     0.021164     0.244366     0.023124
# std             0.265391     0.323761     0.143945     0.429753     0.150311
# min             0.000000     0.000000     0.000000     0.000000     0.000000
# 25%             0.000000     0.000000     0.000000     0.000000     0.000000
# 50%             0.000000     0.000000     0.000000     0.000000     0.000000
# 75%             0.000000     0.000000     0.000000     0.000000     0.000000
# max             1.000000     1.000000     1.000000     1.000000     1.000000
#
#        Benzodiazepine    Methadone       Amphet       Tramad  Hydromorphone  \
# count     5103.000000  5103.000000  5103.000000  5103.000000    5103.000000
# mean         0.263179     0.092887     0.031158     0.025475       0.004899
# std          0.440402     0.290302     0.173762     0.157579       0.069829
# min          0.000000     0.000000     0.000000     0.000000       0.000000
# 25%          0.000000     0.000000     0.000000     0.000000       0.000000
# 50%          0.000000     0.000000     0.000000     0.000000       0.000000
# 75%          1.000000     0.000000     0.000000     0.000000       0.000000
# max          1.000000     1.000000     1.000000     1.000000       1.000000
#
#          OpiateNOS         year        month          day
# count  5103.000000  5103.000000  5103.000000  5103.000000
# mean      0.017245  2015.674897     6.652361    15.260239
# std       0.130195     1.858354     3.451441     8.856963
# min       0.000000  2012.000000     1.000000     1.000000
# 25%       0.000000  2014.000000     4.000000     7.000000
# 50%       0.000000  2016.000000     7.000000    15.000000
# 75%       0.000000  2017.000000    10.000000    23.000000
# max       1.000000  2018.000000    12.000000    31.000000

# %% [markdown]
# ## II. Descriptive Statistics
# ### Demographic Information

# %%
df = df[df.Sex != 'Unknown']

plt.figure(figsize=(4,5))
sns.countplot(df['Sex'])
plt.title('Distribution of Sex', fontsize = 18)
plt.xlabel('Sexes', fontsize = 15)
plt.ylabel('Overdose Frequency', fontsize = 15)
# Out:
# C:\Users\Emilio\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Overdose Frequency')

# %% [markdown]
# In this dataset, males account for 2.85x as many overdose deaths as women.
#
# Let's see sex trends over time.

# %%
male = df[df['Sex']=='Male']["year"].value_counts().sort_index()
fem  = df[df['Sex']=='Female']["year"].value_counts().sort_index()


dfsex = pd.concat([male, fem], axis=1)
dfsex.columns=['Male', 'Female']

# %%
fig, ax = plt.subplots(figsize=(12,6))
dfsex.plot(ax=ax)
plt.title('Drug Overdose Deaths by Sex Over Time \n 2012-2018', fontsize = 20)
ax.set_xlabel('Year', fontsize = 17)
ax.set_ylabel('Overdose Deaths Frequency', fontsize = 17)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(prop={"size":15})

# %% [markdown]
# Overdose deaths among men is considerably higher.
# - Male deaths increased 3X from 2012 to 2018
# - Female deaths increased 1.5X from 2012 to 2018

# %%
# Age data
bins = [0, 21, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, np.inf]
range_names = ['<21', '21-25', '26-30', '31-35', '36-40', '41-45', '46-50', '51-55', '56-60', '61-65', '66-70', '70+']

df['AgeRanges'] = pd.cut(df['Age'], bins, labels = range_names)

# %%
plt.figure(figsize=(14,6))
sns.countplot(df['AgeRanges'], palette = 'copper')
plt.title('Distribution of Age', fontsize = 20)
plt.xlabel('Age Ranges', fontsize = 17)
plt.ylabel('Overdose Frequency', fontsize = 17)
plt.xticks(fontsize = 12)
-plt.yticks(fontsize = 12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7548/4264011847.py in <module>
#       5 plt.ylabel('Overdose Frequency', fontsize = 17)
#       6 plt.xticks(fontsize = 12)
# ----> 7 -plt.yticks(fontsize = 12)
#
# TypeError: bad operand type for unary -: 'tuple'

# %% [markdown]
# - Age range with highest count: 46-50
# - Age range with lowest count: 70+
#
# Taken from earlier stats dataframe:
#
# - Mean age: 42
# - Minimum age: 14
# - Maximum age: 87
#
# Overdose deaths begin to quickly rise in the first half of the 20's, and likewise quickly decreases around age 60

# %%
fig = plt.figure(figsize = (13, 6))
ax = df['Race'].value_counts().plot(kind='barh')
plt.gca().invert_yaxis()
plt.title("Distribution of Race", fontsize = 18)
plt.xlabel("Races", fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel("Overdose Death Frequency", fontsize = 15)
# Out:
# Text(0, 0.5, 'Overdose Death Frequency')

# %% [markdown]
# According to 2020 census:
# https://www.census.gov/quickfacts/CT
#
# - 64.4% White
# - 17% Hispanic
# - 12.7% Black
# - 5% ASian

# %% [markdown]
# Distribution across counties. We'll focus on the 10 most heavily affected.

# %%
top10_county = df['ResidenceCounty'].value_counts()[0:10]

fig = plt.figure(figsize = (12, 6))
top10_county.plot(kind='barh', color = 'blue')
plt.gca().invert_yaxis()
plt.title("Distribution of State of Residence", fontsize = 20)
plt.xlabel("States", fontsize = 18)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel("Overdose Frequency", fontsize = 18)
# Out:
# Text(0, 0.5, 'Overdose Frequency')

# %% [markdown]
# ### Drug Information
# #### Overdose Frequency Over Time
# We'll begin by plotting overall overdose death distribution over time.

# %%
fig, ax = plt.subplots(figsize=(12,6))
plot_data = df.groupby(pd.Grouper(key='Date', freq='M')).count()['Unnamed: 0']
ax = plot_data.plot(ax=ax)
plt.title("Frequency of Overdose Deaths \n 2012 - 2018", fontsize = 16)
plt.xlabel("Timeline", fontsize = 14)
plt.ylabel("Overdose Deaths", fontsize = 14)
# Out:
# Text(0, 0.5, 'Overdose Deaths')

# %% [markdown]
# In terms of our observations:
# - Overdose deaths tend to spike in either direction every three to six months.
# - For comparison, 2018 appears to have experienced roughly 3x as many deaths as 2012.
#
# Let's plot distribution by month to see if there are any identifiable seasonal trends.

# %%
plt.figure(figsize=(13,6))
sns.countplot(df['month'], color = 'orange')
plt.title('Overdose Death Frequency by Month', fontsize = 18)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Overdose Death Frequency', fontsize = 15)
# Out:
# C:\Users\Emilio\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Overdose Death Frequency')

# %% [markdown]
# This confirms our general observation with the previous graph, which is that overdose deaths appear to cycle every few months.

# %% [markdown]
# Break down cases by day of the month.

# %%
plt.figure(figsize=(13,6))
sns.countplot(df['day'], color = 'salmon')
plt.title('Overdose Death Frequency by Day of the Month', fontsize = 18)
plt.xlabel('Day', fontsize = 15)
plt.ylabel('Overdose Death Frequency', fontsize = 15)
# Out:
# C:\Users\Emilio\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Overdose Death Frequency')

# %% [markdown]
# There appears to be a slight increase in cases represented in the first few days of the month, with a slight downwards trend to the end of the month.

# %% [markdown]
# Now we'll shift to visualizing the various drugs of choice involved across deaths.
# ### Overdoses by Drugs of Choice

# %%
her = df[df['Heroin']==1]["year"].value_counts().sort_index()
morph_NH = df[df['Morphine_NotHeroin']==1]["year"].value_counts().sort_index()
coke = df[df['Cocaine']==1]["year"].value_counts().sort_index()
fent = df[df['Fentanyl']==1]["year"].value_counts().sort_index()
fentA = df[df['Fentanyl_Analogue']==1]["year"].value_counts().sort_index()
oxyC = df[df['Oxycodone']==1]["year"].value_counts().sort_index()
oxyM = df[df['Oxymorphone']==1]["year"].value_counts().sort_index()
eth = df[df['Ethanol']==1]["year"].value_counts().sort_index()
hydroC = df[df['Hydrocodone']==1]["year"].value_counts().sort_index()
benzo = df[df['Benzodiazepine']==1]["year"].value_counts().sort_index()
metha = df[df['Methadone']==1]["year"].value_counts().sort_index()
amph = df[df['Amphet']==1]["year"].value_counts().sort_index()
tram = df[df['Tramad']==1]["year"].value_counts().sort_index()
hydroM = df[df['Hydromorphone']==1]["year"].value_counts().sort_index()
other = df[df['Other']==1]["year"].value_counts().sort_index()

# %%
dfdrugs = pd.concat([her, morph_NH, coke, fent, fentA, oxyC, oxyM, eth, hydroC, hydroM, benzo, metha, amph, tram, other], axis=1)
dfdrugs.columns=['Heroin','Morpine, non-Heroin', 'Cocaine', 'Fentanyl', 'Fentanyl analogue', 'Oxycodone', 'Oxymorphone', 'Ethanol',
           'Hydrocodone', 'Hydromorphone', 'Benzodiazepine', 'Methadone', 'Amphet', 'Tram', 'Other']
ax=dfdrugs.plot(kind='bar',figsize=(15,8),fontsize=15)
plt.title("Frequency Distribution of Drugs of Choice by Year", fontsize = 18)
plt.xticks(fontsize = 17, rotation=45)
plt.yticks(fontsize = 17)
plt.ylabel("Overdose Death Frequency", fontsize = 15)
plt.legend(prop={"size":15})

# %%
fig, ax = plt.subplots(figsize=(16,8))
dfdrugs.plot(ax=ax)
plt.title('Timeseries of Drugs of Choice', fontsize = 20)
ax.set_xlabel('Year', fontsize = 17)
ax.set_ylabel('Overdose Deaths Frequency', fontsize = 17)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(prop={"size":12})

# %% [markdown]
# - **Heroin** is by far the most frequently used drug of choice in death by overdose cases. It's usage peaked in 2016 with 500 cases, declining to 400 by 2018.
# - **Benzodiazepine** and **cocaine** are the next most frequent, and likewise took a noticeable upswing over the given timeframe.
# Tracking of fentanyl analogues began in 2017, with an upward trend. This substance outstrips usage of fentanyl proper, both comparatively before analogue introducton and demonstrably after.
# - **Oxycodone** and **Oxymorphone**, both highly potent prescription painkillers, show relatively little change over time. The latter especially acounts for only a few cases per year.
# - Usage of **ethanol** increased substantially over the years, with 2017 reporting roughly 3x as many cases as in 2012.

# %% [markdown]
# ### Overdose Frequency by Location

# %%
fig = plt.figure(figsize = (12, 5))
ax = df['Location'].value_counts().plot(kind='barh', color = 'darkred')
plt.gca().invert_yaxis()
plt.title("Distribution of Locations of Death", fontsize = 18)
plt.xlabel("Locations", fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel("Overdose Death Frequency", fontsize = 15)
# Out:
# Text(0, 0.5, 'Overdose Death Frequency')

# %% [markdown]
# Many overdose deaths occur at home, accounting for approximately 53% of all deaths. This likely because the home environment is where most would feel safe and less afraid of interference when consuming an illicit substance.
#
# Hospitals are the next most frequent (~31%), followed by "other", which represents a considerable variety of outcomes.

# %%
# Other locations
df['LocationifOther'].unique()
# Out:
# array([nan, 'Honey Spot', 'Motel 6', 'Hotel/Motel', 'Park',
#        "Friend's Home", 'Outside', 'Dunkin donuts', "Father's house",
#        'Halfway house', "Friend's House", 'Vacant Apartment',
#        'Abandoned Building', 'Sunnyside Inn', 'Basement', 'Wooded Area',
#        "Friend's Apartment", "Cousin's residence", "Neighbor's Home",
#        'Beach', "Mother's House", 'Public bathroom',
#        'Restaurant Bathroom', 'McDonald Park', "Friend's Residence",
#        "Parent's Home", 'Super 8 Motel Room 219', 'Friends House',
#        'Roadway', 'Econo Lodge', 'Back Stairwell', "Cousin's house",
#        "Friends's Residence", 'Wooded area', "Girlfriend's House",
#        "Girlfriend's Residence", 'In Vehicle',
#        'Under overpass I-91 North', "Neighbor's apartment", 'Motel',
#        'Honeyspot Motor Lodge', 'Cube Smart', "Caretaker's House",
#        'Coventry CT State Boat Launch', 'Travel Inn Motel',
#        "Cousin's House", "Mother's Residence", 'In car in front of',
#        'Outdoor Stairwell', 'Residential Building', 'Foxwoods Casino',
#        'LaQuinta Inn', 'Sidewalk', 'Truck Stop', "Brother's Home",
#        'Outdoors', 'Regal Inn', "relative's home", 'Trailer', 'Carport',
#        'Days Inn', 'Passport Inn #106', 'back patio', "Aunt's Residence",
#        'Homeless', 'Royal Inn', "Godfather's Residence",
#        "Father's Residence", "Parent's house", 'Super 8 Motel',
#        'Roadway in vehicle', 'Pilot Gas Station', 'Front Steps',
#        'FRIEND HOME', 'Backyard', 'Family residence', 'Street',
#        'Howard Johnson Hotel', "friend's house", "Boyfriend's Residence",
#        "Friend's house", 'Crown Plaza Hotel', 'Friends Apartment',
#        'Riverdale Motel', "Tenant's Apartment", 'Stairwell',
#        "Girlfriend's Home", 'Red Roof Inn', 'Driveway', 'Under Pier',
#        'Hotel or Motel', 'Gravel Pit', 'American Motor Lodge',
#        'Econolodge', 'I-91 N Rest Area', "Mother's house", 'Lyme Tavern',
#        "Boyfriend's House", 'Exterior porch', 'Lakeside Motel', 'park',
#        'Hallway', '"Sober House"', 'New Stratford Motor Inn',
#        'Boyfriends House', 'Grange Hall UConn', 'Bubbles Car Wash',
#        'Industrial Area', 'Hotel 0', 'Inside minivan', 'truck cab',
#        'Devon Motel', 'Naugatuck Motor Lodge', 'Carrier Motor Lodge',
#        'Extended Stay Hotel', 'Parking Garage', 'Stonington Motel',
#        "mother's house", "Neighbor's Front Yard", "Ex-Girlfriend's House",
#        'Cummings Park', 'Parking Lot', 'Hotel', 'Winfield Condominiums',
#        'Holiday Inn Express Room 309', 'Customers House',
#        "Niece's Residence", 'Parking Lot Home Depot', 'Residence',
#        "Sister's Residence", "Parent's Residence",
#        'Black Rock State Park', 'Church', 'Days Inn Room 214',
#        "Friend's residence", 'Baldwin Pond', 'Quality Inn', 'in vehicle',
#        'Shelter', 'Kik Builders', 'Sacred Heart University', 'Apartment',
#        'Flamingo Inn Room 147', "parent's residence", "boyfriend's house",
#        "Neighbor's Residence", 'High Ridge Motel', 'Sober House',
#        'In car on road', 'Holiday Inn, Room 205', 'Camper',
#        'Front Porch of', 'Two Trees Inn Foxwood Casino', 'stream',
#        'Budget Inn', 'Rooming House', 'Commercial Art Studio',
#        'Casino Hotel', 'Maple Motel', 'Citco Station Parking Lot',
#        'Colts Park', "Brother's House", 'Walkway', 'Bridge underpass',
#        'Studio Six hotel', 'The Twin Spruce Motel', 'Farm',
#        'Comfort inn Room and suite', 'Rear Staircase', 'Summit Motel',
#        'Price Rite', 'Abandoned garage', 'Parkway Motel',
#        'Former girlfriends', "Mother's Home", 'Rear yard of residence',
#        'Motel/Hotel', 'friends home', 'Hop River Motel',
#        'Westerleigh Housing', 'Warehouse',
#        'Passanger side of vehicle in front of', 'Train Station', 'YMCA',
#        'Holiday Inn Express', 'Mohegan Sun Hotel',
#        "America's Best Value Hotel", 'parents house', "Family's House",
#        'North Boat Launch', 'YMCA-Parking Lot', 'Oxford House',
#        "Counsin's Residence", 'Friend', 'Friends house', 'Group Home',
#        "Sister's house", 'Dorm Room', "Half-sister's home",
#        'American Inn Hotel', 'Days Inn Room 225', 'Grantmoor Motel',
#        'behind building empty parking lot', 'Restaurant',
#        'Stratford Motor Inn Room 1', 'Boat Marina', "Mother's home",
#        'Holiday Inn', 'Parents House', 'Inside Vehicle', 'Deylin Motel',
#        'Leeway Inc', "Father's residence", "Father's Summer cottage",
#        'Rear Alleyway', 'rehab facility', 'Panera Bread - bathroom',
#        'Vehicle side of Road', "Girlfriend's apt.", 'New Haven Hotel',
#        'Apartment Building Stairwell', 'Retreat Center/Sobriety House',
#        'Abandoned Garage', 'Friends Residence', "Grandmother's Residence",
#        'Rehab House', 'Super 8 Cromwell', 'Wooded Area Behind Residence',
#        'Sober  House', "In Car in Margherita's parking lot",
#        'Cedars Hotel', 'Amsterdam Hotel', 'Rodeway Inn', 'Field',
#        'Super 8', "Rear of Inao's Barber Shop", 'Commercial garage',
#        "America's Best Hotel", 'Naugatuck Motor Lodge, Room 105',
#        'Manchester Inn', 'Almar Motel', 'Project More Sober Home', 'Car',
#        'Norwalk Inn', "Howard Johnson's Motel  Room 210", "Father's Home",
#        'Cityside Inn', 'Ramada Inn', 'Woods', 'Flamingo Inn',
#        'Detention Center', 'Motel 6, Room 167', 'Cedar Grove Cemetery',
#        "Sister's Home", 'Regal Inn Hotel', 'Wooded Area Near',
#        'Sober home', 'car', 'Hilton Garden Inn', 'La Quinta Inn',
#        'Friends home', 'Behind Building', "Male Companion's House",
#        'Lake Warmaug', "Relative's Home", 'Appalachian Trail-Woods',
#        "Girlfriend's home", "Friend's home", 'Bushnell Park',
#        'Milford Inn', 'Apt. Building Basement', 'Rear Yard',
#        "Dunkin' Donuts/J&T Shell Gas Station", 'abandoned house',
#        'Suites at Yale', 'Choice Pet Suppy rear', 'work place', 'Vehicle',
#        'Plymouth Motor Lodge Room 108', 'Vacant Lot Behind',
#        'Other Residence', "Brother's Residence", 'Marriott Hotel',
#        'Public Restroom', "mother's residence", "Dad's Home",
#        'Halfway House', "Mother's residence", 'Madison Motor Inn',
#        'West Haven Beach', 'Taco Bell', "Grandfather's House",
#        'Temporary Residence', 'Post Office', 'Shopping Area',
#        'parking lot', "girlfriend's house", "Parent's residence",
#        'Bathroom', "Sister's Apartment", 'Flagship Inn',
#        'Cos Cob Inn Bed and Breakfast', 'friends house', 'Work',
#        'Boarding House', "Brother's house", 'Abandon House',
#        'Roadway Inn', 'rear yard', 'Area to west of Railroad Tracks',
#        "Friends' Home", 'Best Way Inn', 'EconoLoge',
#        'Super 8 Motel, Room 206', 'Westport Inn',
#        'Residence Inn/Marriott Room 615', 'Public Building', 'Rear Porch',
#        'The Inn', 'Boyfriends Residence', 'Rear Parking Lot',
#        'Shoreline Hotel', 'By Railroad Tracks'], dtype=object)

# %% [markdown]
# This list appears to primarily consist of hotel rooms and others' homes
